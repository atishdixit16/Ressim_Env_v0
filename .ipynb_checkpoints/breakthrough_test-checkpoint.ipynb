# %%
import numpy as np
from tqdm import trange
import matplotlib.pyplot as plt

from ressim_enviroment import resSimEnv_v1

# %%
n_step_ = 100
dt_ = 1e-3
mu_w_ = 1.0
mu_o_ = 2.0
lx_ = 2.0
ly_ = 2.0
phi_ = 0.1
k_ = 1.0
env = resSimEnv_v1(11, n_steps=n_step_, dt=dt_, mu_w = mu_w_, mu_o = mu_o_, phi=phi_, k=k_)
n_action = env.action_space.n
n_episodes = 1
n_ep_steps = 5
cumRewards = []
for i in range(n_episodes):
    state = env.reset()
    cumR = 0.0
    sw_p1 = [env.get_sw(0,0)]
    sw_p2 = [env.get_sw(-1,0)]
    for j in trange(n_ep_steps):
        # env.render(i,j)
        action = 6
        state, reward, done, info = env.step(action)
        sw_p1.append(env.get_sw(0,0))
        sw_p2.append(env.get_sw(-1,0))
        cumR += reward
    cumRewards.append(cumR)
    # print('Episode: '+str(i+1)+', reward:'+str(round(cumR,1)))
# Out:
#  80%|████████  | 4/5 [00:11<00:03,  3.03s/it]

# %%
plt.clf()
x = range(n_ep_steps+1)
plt.plot(x, sw_p1, x, sw_p2 )
plt.grid('True')
plt.xlabel('steps')
plt.ylabel('water saturation at producer')
plt.hlines(y=0.8, xmin=0, xmax=n_ep_steps, linestyles='dashed')
plt.title('Environment: ResSim-v1\nnstep='+str(n_step_)+'; dt='+str(dt_))
plt.legend(('Sw_producer_1', 'Sw_producer_2'))
plt.show()

# %%
print(sw_p1+sw_p2)
# Out:
# [0.2, 0.45865381675608874, 0.5892657136221551, 0.6445279428928417, 0.6731218073203015, 0.6909313798050338, 0.2, 0.2, 0.2, 0.5066477874739208, 0.5634278763741544, 0.5968996371143062]
